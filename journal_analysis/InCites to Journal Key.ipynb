# %%
import funcy
import difflib
import pandas as pd
import numpy as np
import re
import string
from fuzzywuzzy import fuzz
from os.path import join


RAW_DATA = '/Users/lrraymond13/MIT/Furman_RA_2016/journal_analysis/Data/RawData'
INCITES = 'InCitesJournalGrid.csv'
JOURNAL_KEY = 'Furman_Journal_Key2016.csv'

# %%
# 1. Check that the spellings in the JOURNAL KEY uniquely identify a journal. 
# If there are multiple spellings for the same journal, adjust the Journal ID. 
# Specifically, in column AdjustedJournalID enter the same number from column JournalID corresponding
# to one of the spellings for all alternative spellings. When in doubt, leave as separate journals 
# i.e. with separate JournalID numbers.

# 3. Pair the spelling from InCites with the one in the attached file, for each identified unique AdjustedJournalID. 

# 4. Add in the Excel file the InCites spelling, along with Total Cites, Journal Impact Factor and Eigenfactor 
# from InCites.

# %%
# import journal key file, check each spelling is unique
jk_df = pd.read_csv(join(RAW_DATA, JOURNAL_KEY))
jk_df.columns = map(lambda x: '_'.join(x.split(' ')).upper(), jk_df.columns)
print jk_df.columns
# Out:
# Index([u'PUBLICATION_TITLE', u'JOURNALID', u'ADJUSTEDJOURNALID',
#        u'INCITES_SPELLING'],
#       dtype='object')

# %%
# Check the length of unique pub titles is same as length of series
def check_unique(uniq_ser):
    # check if dup values in unique series
    unique_titles = uniq_ser.unique()
    return len(unique_titles) == uniq_ser.shape[0]

# %%
check_unique(jk_df.loc[:, 'PUBLICATION_TITLE'])
# Out:
# True

# %%
# Check if there are any modifications caused by changing journal to uppercase and stripping extraneous chars

# %%
# string cleaning functions
def trans_remov_punc(to_change, change_to):
    # removes specified punctuation using string maketrans (very fast, C lookups)
    #returns partially evaluated fnc
    trantab = string.maketrans(to_change, change_to)
    return funcy.func_partial(lambda x: x.translate(trantab))


def standardize_whitespace(pub_str):
    return ' '.join(filter(None, pub_str.split(' ')))


def remove_punc(pub_str):
    # function to remove punctuation
    nonelst = ' '*len(string.punctuation)
    fn = trans_remov_punc(string.punctuation, nonelst)
    new_str = fn(pub_str)
    # standardize spaces
    return standardize_whitespace(new_str)


def has_year(pub_str):
    # checks if string contains a year
    # each string should always have punctuation removed
    if isinstance(pub_str, str):
        pub_str = pub_str.split(' ')
    nums = [int(s) for s in pub_str if s.isdigit()]
    return any(map(lambda x: 1900 < x < 2018, nums))


def seperate_IEEE_IET(fnc_str):
# many strings are title, IEEE while in incites matching file formar is IEEE title. 
    if not isinstance(fnc_str, str):
        strs = ' '.join(fnc_str)
    strs = fnc_str.rsplit(', ', 1)
    return ' '.join(strs[::-1])


def remove_acronym(pub_str):
    # removes acronyms enclosed in parens ex: (SAS)
    re_match = " \(\S+\)"
    if not re.search(re_match, pub_str, re.IGNORECASE):
        return pub_str
    r = re.compile(r" \(\S+\)", re.IGNORECASE)
    new_str = r.sub(r'', pub_str)
    return new_str


def remove_year(pub_str):
    re_match = "\d{4}"
    if not re.search(re_match, pub_str, re.IGNORECASE):
        return pub_str
    r = re.compile(r"\d{4}", re.IGNORECASE)
    new_str = r.sub(r'', pub_str)
    return new_str


def clean_pubname(pub_str):
    if ', ' in pub_str:
        pub_str = seperate_IEEE_IET(pub_str)
    no_ac = remove_acronym(pub_str)
    # now remove punctuation
    no_pnc = remove_punc(no_ac)
    is_year = has_year(no_pnc)
    if is_year:
        # remove year
        no_pnc = remove_year(no_pnc)
    return standardize_whitespace(no_pnc)
    

def is_conf(pub_str, conf_strings=None):
    # checks if string appears ot be a conference
    if conf_strings is None:
        conf_strings = ['SYMPOSIUM', 'CONFERENCE',
                        'COLLOQUIUM', 'CONGRESS', 'ANNUAL', 'FORUM', 'WORKSHOP', 'SEMINAR']
    is_conf = any(map(lambda x: x in pub_str, conf_strings))
    # check if date exists in any of the string
    is_year = has_year(pub_str)
    if is_conf or is_year:
        return 1
    return 0

# %%
clean_pubname('Service-Oriented Computing and Applications (SOCA), 2009 IEEE International Conference on')
# Out:
# 'IEEE International Conference on Service Oriented Computing and Applications'

# %%
jk_df['CLEAN_PUB'] = jk_df['PUBLICATION_TITLE'].apply(clean_pubname)
check_unique(jk_df.loc[:, 'CLEAN_PUB'])
# Out:
# False

# %%
# check which are not the same
dups = jk_df[jk_df.duplicated(subset=['CLEAN_PUB'], keep=False)]

# %%
dups
# Out:
#                                        PUBLICATION_TITLE  JOURNALID  \
# 16     3D Imaging (IC3D), 2012 International Conferen...         17
# 17     3D Imaging (IC3D), 2013 International Conferen...         18
# 22     3D Systems Integration Conference (3DIC), 2010...         23
# 23     3D Systems Integration Conference (3DIC), 2011...         24
# 24     3D Systems Integration Conference (3DIC), 2013...         25
# 25     3D User Interfaces (3DUI), 2010 IEEE Symposium on         26
# 26     3D User Interfaces (3DUI), 2011 IEEE Symposium on         27
# 27     3D User Interfaces (3DUI), 2012 IEEE Symposium on         28
# 28     3D User Interfaces (3DUI), 2013 IEEE Symposium on         29
# 29     3D User Interfaces (3DUI), 2014 IEEE Symposium on         30
# 30     3D User Interfaces, 2006. 3DUI 2006. IEEE Symp...         31
# 32     3D User Interfaces, 2008. 3DUI 2008. IEEE Symp...         33
# 33     3D User Interfaces, 2009. 3DUI 2009. IEEE Symp...         34
# 36     3DTV Conference: The True Vision - Capture, Tr...         37
# 37     3DTV Conference: The True Vision - Capture, Tr...         38
# 38     3DTV Conference: The True Vision - Capture, Tr...         39
# 39     3DTV-Conference: The True Vision - Capture, Tr...         40
# 40     3DTV-Conference: The True Vision - Capture, Tr...         41
# 41     3DTV-Conference: The True Vision - Capture, Tr...         42
# 68     Acoustics Speech and Signal Processing (ICASSP...         69
# 69     Acoustics, Speech and Signal Processing (ICASS...         70
# 70     Acoustics, Speech and Signal Processing (ICASS...         71
# 71     Acoustics, Speech and Signal Processing (ICASS...         72
# 72     Acoustics, Speech and Signal Processing (ICASS...         73
# 74     Acoustics, Speech and Signal Processing, 2007....         75
# 75     Acoustics, Speech and Signal Processing, 2008....         76
# 76     Acoustics, Speech and Signal Processing, 2009....         77
# 78     Acoustics, Speech, and Signal Processing (ICAS...         79
# 101    Actual Problems of Electron Devices Engineerin...        102
# 102    Actual Problems of Electron Devices Engineerin...        103
# ...                                                  ...        ...
# 16491  Wireless Technology and Applications (ISWTA), ...      16492
# 16492  Wireless Technology and Applications (ISWTA), ...      16493
# 16499  Wireless Telecommunications Symposium (WTS), 2010      16500
# 16500  Wireless Telecommunications Symposium (WTS), 2011      16501
# 16501  Wireless Telecommunications Symposium (WTS), 2012      16502
# 16502  Wireless Telecommunications Symposium (WTS), 2013      16503
# 16503  Wireless Telecommunications Symposium (WTS), 2014      16504
# 16504        Wireless Telecommunications Symposium, 2004      16505
# 16505        Wireless Telecommunications Symposium, 2005      16506
# 16507  Wireless Telecommunications Symposium, 2007. W...      16508
# 16508  Wireless Telecommunications Symposium, 2008. W...      16509
# 16509  Wireless Telecommunications Symposium, 2009. W...      16510
# 16515  Wireless, Mobile and Multimedia Networks, 2006...      16516
# 16516  Wireless, Mobile and Multimedia Networks, 2008...      16517
# 16527  Workload Characterization (IISWC), 2010 IEEE I...      16528
# 16528  Workload Characterization (IISWC), 2011 IEEE I...      16529
# 16529  Workload Characterization (IISWC), 2012 IEEE I...      16530
# 16530  Workload Characterization (IISWC), 2013 IEEE I...      16531
# 16531  Workload Characterization (IISWC), 2014 IEEE I...      16532
# 16537  Workload Characterization, 2006 IEEE Internati...      16538
# 16539  Workload Characterization, 2008. IISWC 2008. I...      16540
# 16540  Workload Characterization, 2009. IISWC 2009. I...      16541
# 16542              World Automation Congress (WAC), 2010      16543
# 16543              World Automation Congress (WAC), 2012      16544
# 16544              World Automation Congress (WAC), 2014      16545
# 16550  World of Wireless Mobile and Multimedia Networ...      16551
# 16553  World of Wireless, Mobile and Multimedia Netwo...      16554
# 16554  World of Wireless, Mobile and Multimedia Netwo...      16555
# 16556  World of Wireless, Mobile and Multimedia Netwo...      16557
# 16558  World of Wireless, Mobile and Multimedia Netwo...      16559
#
#        ADJUSTEDJOURNALID  INCITES_SPELLING  \
# 16                   NaN               NaN
# 17                   NaN               NaN
# 22                   NaN               NaN
# 23                   NaN               NaN
# 24                   NaN               NaN
# 25                   NaN               NaN
# 26                   NaN               NaN
# 27                   NaN               NaN
# 28                   NaN               NaN
# 29                   NaN               NaN
# 30                   NaN               NaN
# 32                   NaN               NaN
# 33                   NaN               NaN
# 36                   NaN               NaN
# 37                   NaN               NaN
# 38                   NaN               NaN
# 39                   NaN               NaN
# 40                   NaN               NaN
# 41                   NaN               NaN
# 68                   NaN               NaN
# 69                   NaN               NaN
# 70                   NaN               NaN
# 71                   NaN               NaN
# 72                   NaN               NaN
# 74                   NaN               NaN
# 75                   NaN               NaN
# 76                   NaN               NaN
# 78                   NaN               NaN
# 101                  NaN               NaN
# 102                  NaN               NaN
# ...                  ...               ...
# 16491                NaN               NaN
# 16492                NaN               NaN
# 16499                NaN               NaN
# 16500                NaN               NaN
# 16501                NaN               NaN
# 16502                NaN               NaN
# 16503                NaN               NaN
# 16504                NaN               NaN
# 16505                NaN               NaN
# 16507                NaN               NaN
# 16508                NaN               NaN
# 16509                NaN               NaN
# 16515                NaN               NaN
# 16516                NaN               NaN
# 16527                NaN               NaN
# 16528                NaN               NaN
# 16529                NaN               NaN
# 16530                NaN               NaN
# 16531                NaN               NaN
# 16537                NaN               NaN
# 16539                NaN               NaN
# 16540                NaN               NaN
# 16542                NaN               NaN
# 16543                NaN               NaN
# 16544                NaN               NaN
# 16550                NaN               NaN
# 16553                NaN               NaN
# 16554                NaN               NaN
# 16556                NaN               NaN
# 16558                NaN               NaN
#
#                                                CLEAN_PUB
# 16                International Conference on 3D Imaging
# 17                International Conference on 3D Imaging
# 22     IEEE International 3D Systems Integration Conf...
# 23     IEEE International 3D Systems Integration Conf...
# 24     IEEE International 3D Systems Integration Conf...
# 25                  IEEE Symposium on 3D User Interfaces
# 26                  IEEE Symposium on 3D User Interfaces
# 27                  IEEE Symposium on 3D User Interfaces
# 28                  IEEE Symposium on 3D User Interfaces
# 29                  IEEE Symposium on 3D User Interfaces
# 30             3DUI IEEE Symposium on 3D User Interfaces
# 32             3DUI IEEE Symposium on 3D User Interfaces
# 33             3DUI IEEE Symposium on 3D User Interfaces
# 36     3DTV Conference The True Vision Capture Transm...
# 37     3DTV Conference The True Vision Capture Transm...
# 38     3DTV Conference The True Vision Capture Transm...
# 39     3DTV Conference The True Vision Capture Transm...
# 40     3DTV Conference The True Vision Capture Transm...
# 41     3DTV Conference The True Vision Capture Transm...
# 68     IEEE International Conference on Acoustics Spe...
# 69     IEEE International Conference on Acoustics Spe...
# 70     IEEE International Conference on Acoustics Spe...
# 71     IEEE International Conference on Acoustics Spe...
# 72     IEEE International Conference on Acoustics Spe...
# 74     ICASSP IEEE International Conference on Acoust...
# 75     ICASSP IEEE International Conference on Acoust...
# 76     ICASSP IEEE International Conference on Acoust...
# 78     IEEE International Conference on Acoustics Spe...
# 101    International Conference on Actual Problems of...
# 102    International Conference on Actual Problems of...
# ...                                                  ...
# 16491  IEEE Symposium on Wireless Technology and Appl...
# 16492  IEEE Symposium on Wireless Technology and Appl...
# 16499              Wireless Telecommunications Symposium
# 16500              Wireless Telecommunications Symposium
# 16501              Wireless Telecommunications Symposium
# 16502              Wireless Telecommunications Symposium
# 16503              Wireless Telecommunications Symposium
# 16504              Wireless Telecommunications Symposium
# 16505              Wireless Telecommunications Symposium
# 16507          WTS Wireless Telecommunications Symposium
# 16508          WTS Wireless Telecommunications Symposium
# 16509          WTS Wireless Telecommunications Symposium
# 16515  IET International Conference on Wireless Mobil...
# 16516  IET International Conference on Wireless Mobil...
# 16527  IEEE International Symposium on Workload Chara...
# 16528  IEEE International Symposium on Workload Chara...
# 16529  IEEE International Symposium on Workload Chara...
# 16530  IEEE International Symposium on Workload Chara...
# 16531  IEEE International Symposium on Workload Chara...
# 16537  IEEE International Symposium on Workload Chara...
# 16539  IISWC IEEE International Symposium on Workload...
# 16540  IISWC IEEE International Symposium on Workload...
# 16542                          World Automation Congress
# 16543                          World Automation Congress
# 16544                          World Automation Congress
# 16550  IEEE International Symposium on a World of Wir...
# 16553  IEEE International Symposium on a World of Wir...
# 16554  IEEE International Symposium on a World of Wir...
# 16556  WoWMoM International Symposium on a World of W...
# 16558  WoWMoM International Symposium on a World of W...
#
# [3736 rows x 5 columns]

# %%
# for each of the duplicates, adjust any subsequent journal ids
standard_dups = jk_df.loc[jk_df.duplicated(subset=['CLEAN_PUB'], keep='last'), ['CLEAN_PUB', 'JOURNALID']]
standard_dups.rename(columns={'JOURNALID': 'DEDUP_JOURNALID'}, inplace=True)
jk_df2 = pd.merge(
    left=jk_df, right=standard_dups.loc[:, ['CLEAN_PUB','DEDUP_JOURNALID']],
                  left_on='CLEAN_PUB', right_on='CLEAN_PUB', how='left')

# %%
jk_df2['CONF_FLAG'] = jk_df2['CLEAN_PUB'].apply(is_conf)

# %%
incites_df = pd.read_csv(join(RAW_DATA, INCITES), skiprows=1)
incites_df.columns = map(lambda x: '_'.join(x.split(' ')).upper(), incites_df.columns)

# %%
# standardize journal title to uppercase and remove punctuation
incites_df['CLEAN_PUB'] = incites_df['FULL_JOURNAL_TITLE'].apply(clean_pubname)

# %%
# merge the jk_df2 clean pub name with the incites df
exact_matches = pd.merge(
    left=incites_df, right=jk_df2, left_on='CLEAN_PUB', right_on='CLEAN_PUB', how='inner')

# %%
exact_matches
# Out:
#      RANK                                 FULL_JOURNAL_TITLE TOTAL_CITES  \
# 0     602               IEEE Industrial Electronics Magazine         518
# 1     702                   IEEE Transactions on Cybernetics       2,246
# 2     728  IEEE Transactions on Neural Networks and Learn...      12,919
# 3     782        IEEE Transactions on Industrial Informatics       3,779
# 4    1266                      IEEE Journal of Photovoltaics       2,469
# 5    1271            IEEE Transactions on Sustainable Energy       2,149
# 6    1330           IEEE Computational Intelligence Magazine         634
# 7    1738                    IEEE Transactions on Smart Grid       4,753
# 8    1796  IEEE Journal of Emerging and Selected Topics i...         473
# 9    1950                 IEEE Circuits and Systems Magazine         550
# 10   2255                 IEEE Vehicular Technology Magazine         510
# 11   2378  IEEE Transactions on Automation Science and En...       1,953
# 12   2569  IEEE Journal of Selected Topics in Signal Proc...       2,763
# 13   2816  IEEE Transactions on Information Forensics and...       3,185
# 14   2974            IEEE Transactions on Services Computing         738
# 15   3098  IEEE Transactions on Terahertz Science and Tec...         992
# 16   3250         IEEE Geoscience and Remote Sensing Letters       5,572
# 17   3365                             IEEE Photonics Journal       2,498
# 18   3451  IEEE Journal of Selected Topics in Applied Ear...       3,033
# 19   3530                               IEEE Systems Journal       1,076
# 20   3577  IEEE Journal of Biomedical and Health Informatics         779
# 21   3754                      IEEE Transactions on Robotics       7,905
# 22   3780  IEEE Transactions on Biomedical Circuits and S...       1,307
# 23   3877                             IEEE Magnetics Letters         184
# 24   4004                      Journal of Display Technology       1,919
# 25   4122  IEEE Transactions on Audio Speech and Language...       3,264
# 26   4134           IEEE Transactions on Affective Computing         520
# 27   4361         IEEE Transactions on Human-Machine Systems         239
# 28   4534     IEEE Antennas and Wireless Propagation Letters       5,502
# 29   4992  IEEE-ACM Transactions on Computational Biology...       1,686
# ..    ...                                                ...         ...
# 35   5240                              IET Nanobiotechnology         272
# 36   5906                    IET Electric Power Applications         848
# 37   6355                                        IEEE Access         253
# 38   6449  IEEE-ACM Transactions on Audio Speech and Lang...         247
# 39   6544  IEEE Transactions on Autonomous Mental Develop...         232
# 40   6761  IEEE Transactions on Components Packaging and ...       3,825
# 41   6856         IEEE Transactions on Learning Technologies         329
# 42   6856         IEEE Transactions on Learning Technologies         329
# 43   7129                                    IT Professional         350
# 44   7295                       IEEE Transactions on Haptics         356
# 45   7379                           IET Information Security         252
# 46   7424  IEEE Transactions on Computational Intelligenc...         249
# 47   7542               IET Science Measurement & Technology         405
# 48   8075                              IET Signal Processing         539
# 49   8149                               IET Image Processing         537
# 50   8231                  IET Intelligent Transport Systems         449
# 51   8348              IET Microwaves Antennas & Propagation       1,325
# 52   8634                                     IET Biometrics          86
# 53   8634                                IET Systems Biology         323
# 54   9093                                 IEEE Design & Test         745
# 55   9387                                 IET Communications       1,512
# 56   9584                     IET Circuits Devices & Systems         311
# 57   9681                                IET Computer Vision         284
# 58   9755                                IET Optoelectronics         198
# 59   9766                                         IEEE Pulse         160
# 60  10247                                       IET Software         145
# 61  10269                     Engineering Management Journal         231
# 62  10269                     Engineering Management Journal         231
# 63  10269     Journal of Systems Engineering and Electronics         643
# 64  10507                               China Communications         275
#
#    JOURNAL_IMPACT_FACTOR  EIGENFACTOR_SCORE  \
# 0                  5.303            0.00265
# 1                  4.943            0.01017
# 2                  4.854            0.02248
# 3                  4.708            0.01639
# 4                  3.736            0.00960
# 5                  3.727            0.01171
# 6                  3.647            0.00165
# 7                   3.19            0.02922
# 8                  3.129            0.00305
# 9                      3            0.00142
# 10                 2.783            0.00250
# 11                 2.696            0.00746
# 12                 2.569            0.01607
# 13                 2.441            0.01439
# 14                 2.365            0.00330
# 15                 2.298            0.00540
# 16                 2.228            0.01608
# 17                 2.177            0.01149
# 18                 2.145            0.01095
# 19                 2.114            0.00444
# 20                 2.093            0.00317
# 21                 2.028            0.01326
# 22                 2.018            0.00621
# 23                 1.978            0.00115
# 24                 1.925            0.00494
# 25                 1.877            0.01105
# 26                 1.873            0.00280
# 27                   1.8            0.00079
# 28                 1.751            0.02613
# 29                 1.609            0.00583
# ..                   ...                ...
# 35                 1.541            0.00050
# 36                 1.358            0.00276
# 37                 1.249            0.00198
# 38                 1.225            0.00097
# 39                 1.205            0.00085
# 40                 1.151            0.00804
# 41                 1.129            0.00110
# 42                 1.129            0.00110
# 43                 1.067            0.00094
# 44                 1.031            0.00139
# 45                 1.013            0.00108
# 46                     1            0.00126
# 47                 0.982            0.00128
# 48                 0.873            0.00204
# 49                  0.86            0.00183
# 50                 0.843            0.00136
# 51                 0.817            0.00694
# 52                 0.764            0.00049
# 53                 0.764            0.00090
# 54                 0.681            0.00182
# 55                 0.624            0.00620
# 56                  0.59            0.00109
# 57                 0.573            0.00096
# 58                 0.559            0.00051
# 59                 0.558            0.00077
# 60                 0.473            0.00057
# 61                 0.468            0.00025
# 62                 0.468            0.00025
# 63                 0.468            0.00128
# 64                 0.424            0.00090
#
#                                             CLEAN_PUB  \
# 0                IEEE Industrial Electronics Magazine
# 1                    IEEE Transactions on Cybernetics
# 2   IEEE Transactions on Neural Networks and Learn...
# 3         IEEE Transactions on Industrial Informatics
# 4                       IEEE Journal of Photovoltaics
# 5             IEEE Transactions on Sustainable Energy
# 6            IEEE Computational Intelligence Magazine
# 7                     IEEE Transactions on Smart Grid
# 8   IEEE Journal of Emerging and Selected Topics i...
# 9                  IEEE Circuits and Systems Magazine
# 10                 IEEE Vehicular Technology Magazine
# 11  IEEE Transactions on Automation Science and En...
# 12  IEEE Journal of Selected Topics in Signal Proc...
# 13  IEEE Transactions on Information Forensics and...
# 14            IEEE Transactions on Services Computing
# 15  IEEE Transactions on Terahertz Science and Tec...
# 16         IEEE Geoscience and Remote Sensing Letters
# 17                             IEEE Photonics Journal
# 18  IEEE Journal of Selected Topics in Applied Ear...
# 19                               IEEE Systems Journal
# 20  IEEE Journal of Biomedical and Health Informatics
# 21                      IEEE Transactions on Robotics
# 22  IEEE Transactions on Biomedical Circuits and S...
# 23                             IEEE Magnetics Letters
# 24                      Journal of Display Technology
# 25  IEEE Transactions on Audio Speech and Language...
# 26           IEEE Transactions on Affective Computing
# 27         IEEE Transactions on Human Machine Systems
# 28     IEEE Antennas and Wireless Propagation Letters
# 29  IEEE ACM Transactions on Computational Biology...
# ..                                                ...
# 35                              IET Nanobiotechnology
# 36                    IET Electric Power Applications
# 37                                        IEEE Access
# 38  IEEE ACM Transactions on Audio Speech and Lang...
# 39  IEEE Transactions on Autonomous Mental Develop...
# 40  IEEE Transactions on Components Packaging and ...
# 41         IEEE Transactions on Learning Technologies
# 42         IEEE Transactions on Learning Technologies
# 43                                    IT Professional
# 44                       IEEE Transactions on Haptics
# 45                           IET Information Security
# 46  IEEE Transactions on Computational Intelligenc...
# 47                 IET Science Measurement Technology
# 48                              IET Signal Processing
# 49                               IET Image Processing
# 50                  IET Intelligent Transport Systems
# 51                IET Microwaves Antennas Propagation
# 52                                     IET Biometrics
# 53                                IET Systems Biology
# 54                                   IEEE Design Test
# 55                                 IET Communications
# 56                       IET Circuits Devices Systems
# 57                                IET Computer Vision
# 58                                IET Optoelectronics
# 59                                         IEEE Pulse
# 60                                       IET Software
# 61                     Engineering Management Journal
# 62                     Engineering Management Journal
# 63     Journal of Systems Engineering and Electronics
# 64                               China Communications
#
#                                     PUBLICATION_TITLE  JOURNALID  \
# 0               Industrial Electronics Magazine, IEEE       8915
# 1                   Cybernetics, IEEE Transactions on       3358
# 2   Neural Networks and Learning Systems, IEEE Tra...      11668
# 3        Industrial Informatics, IEEE Transactions on       8970
# 4                      Photovoltaics, IEEE Journal of      12495
# 5            Sustainable Energy, IEEE Transactions on      15045
# 6           Computational Intelligence Magazine, IEEE       2384
# 7                    Smart Grid, IEEE Transactions on      14442
# 8   Emerging and Selected Topics in Power Electron...       4809
# 9                 Circuits and Systems Magazine, IEEE       1640
# 10                Vehicular Technology Magazine, IEEE      16119
# 11  Automation Science and Engineering, IEEE Trans...       1133
# 12  Selected Topics in Signal Processing, IEEE Jou...      13880
# 13  Information Forensics and Security, IEEE Trans...       9149
# 14           Services Computing, IEEE Transactions on      14134
# 15  Terahertz Science and Technology, IEEE Transac...      15494
# 16        Geoscience and Remote Sensing Letters, IEEE       5563
# 17                            Photonics Journal, IEEE      12471
# 18  Selected Topics in Applied Earth Observations ...      13878
# 19                              Systems Journal, IEEE      15241
# 20  Biomedical and Health Informatics, IEEE Journa...       1322
# 21                     Robotics, IEEE Transactions on      13708
# 22  Biomedical Circuits and Systems, IEEE Transact...       1335
# 23                            Magnetics Letters, IEEE      10423
# 24                     Display Technology, Journal of       3922
# 25  Audio, Speech, and Language Processing, IEEE T...       1060
# 26          Affective Computing, IEEE Transactions on        515
# 27        Human-Machine Systems, IEEE Transactions on       6000
# 28    Antennas and Wireless Propagation Letters, IEEE        718
# 29  Computational Biology and Bioinformatics, IEEE...       2175
# ..                                                ...        ...
# 35                             Nanobiotechnology, IET      11373
# 36                   Electric Power Applications, IET       4150
# 37                                       Access, IEEE         64
# 38  Audio, Speech, and Language Processing, IEEE/A...       1061
# 39  Autonomous Mental Development, IEEE Transactio...       1166
# 40  Components, Packaging and Manufacturing Techno...       2132
# 41        Learning Technologies, IEEE Transactions on      10263
# 42        Learning Technologies, IEEE Transactions on      10263
# 43                                    IT Professional      10140
# 44                      Haptics, IEEE Transactions on       5762
# 45                          Information Security, IET       9270
# 46  Computational Intelligence and AI in Games, IE...       2220
# 47             Science, Measurement & Technology, IET      13789
# 48                             Signal Processing, IET      14302
# 49                              Image Processing, IET       8808
# 50                 Intelligent Transport Systems, IET       9920
# 51            Microwaves, Antennas & Propagation, IET      10963
# 52                                    Biometrics, IET       1424
# 53                               Systems Biology, IET      15222
# 54                                Design & Test, IEEE       3616
# 55                                Communications, IET       2093
# 56                   Circuits, Devices & Systems, IET       1687
# 57                               Computer Vision, IET       2891
# 58                               Optoelectronics, IET      12050
# 59                                        Pulse, IEEE      13013
# 60                                      Software, IET      14802
# 61                     Engineering Management Journal       5025
# 62                     Engineering Management Journal       5025
# 63    Systems Engineering and Electronics, Journal of      15234
# 64                              Communications, China       2064
#
#     ADJUSTEDJOURNALID  INCITES_SPELLING  DEDUP_JOURNALID  CONF_FLAG
# 0                 NaN               NaN              NaN          0
# 1                 NaN               NaN              NaN          0
# 2                 NaN               NaN              NaN          0
# 3                 NaN               NaN              NaN          0
# 4                 NaN               NaN              NaN          0
# 5                 NaN               NaN              NaN          0
# 6                 NaN               NaN              NaN          0
# 7                 NaN               NaN              NaN          0
# 8                 NaN               NaN              NaN          0
# 9                 NaN               NaN              NaN          0
# 10                NaN               NaN              NaN          0
# 11                NaN               NaN              NaN          0
# 12                NaN               NaN              NaN          0
# 13                NaN               NaN              NaN          0
# 14                NaN               NaN              NaN          0
# 15                NaN               NaN              NaN          0
# 16                NaN               NaN              NaN          0
# 17                NaN               NaN              NaN          0
# 18                NaN               NaN              NaN          0
# 19                NaN               NaN              NaN          0
# 20                NaN               NaN              NaN          0
# 21                NaN               NaN              NaN          0
# 22                NaN               NaN              NaN          0
# 23                NaN               NaN              NaN          0
# 24                NaN               NaN              NaN          0
# 25                NaN               NaN              NaN          0
# 26                NaN               NaN              NaN          0
# 27                NaN               NaN              NaN          0
# 28                NaN               NaN              NaN          0
# 29                NaN               NaN              NaN          0
# ..                ...               ...              ...        ...
# 35                NaN               NaN              NaN          0
# 36                NaN               NaN              NaN          0
# 37                NaN               NaN              NaN          0
# 38                NaN               NaN              NaN          0
# 39                NaN               NaN              NaN          0
# 40                NaN               NaN              NaN          0
# 41                NaN               NaN              NaN          0
# 42                NaN               NaN              NaN          0
# 43                NaN               NaN              NaN          0
# 44                NaN               NaN              NaN          0
# 45                NaN               NaN              NaN          0
# 46                NaN               NaN              NaN          0
# 47                NaN               NaN              NaN          0
# 48                NaN               NaN              NaN          0
# 49                NaN               NaN              NaN          0
# 50                NaN               NaN              NaN          0
# 51                NaN               NaN              NaN          0
# 52                NaN               NaN              NaN          0
# 53                NaN               NaN              NaN          0
# 54                NaN               NaN              NaN          0
# 55                NaN               NaN              NaN          0
# 56                NaN               NaN              NaN          0
# 57                NaN               NaN              NaN          0
# 58                NaN               NaN              NaN          0
# 59                NaN               NaN              NaN          0
# 60                NaN               NaN              NaN          0
# 61                NaN               NaN              NaN          0
# 62                NaN               NaN              NaN          0
# 63                NaN               NaN              NaN          0
# 64                NaN               NaN              NaN          0
#
# [65 rows x 12 columns]

# %%
not_match = jk_df2.loc[~jk_df2['CLEAN_PUB'].isin(exact_matches['CLEAN_PUB']), :]
not_match.set_index(keys='CLEAN_PUB', drop=True, inplace=True)

not_match_incites = incites_df.loc[~incites_df['CLEAN_PUB'].isin(exact_matches.index), :]
not_match_incites.set_index(keys='CLEAN_PUB', drop=True, inplace=True)

# %%
def get_close_matches(x, match_index):
    match = difflib.get_close_matches(x, match_index)
    if len(match) == 0:
        return None
    return match[0]

# %%
not_match.index = not_match.index.map(lambda x: get_close_matches(x, not_match_incites.index))

# %%
strip_yearly_info('3-D Digital Imaging and Modeling, 2001. Proceedings. Third International Conference on')
# Out:
# set(['!', '#', '"', '%', '$', "'", '&', ')', '+', '*', '-', ',', '/', '.', ';', ':', '=', '<', '?', '>', '@', '[', ']', '\\', '_', '^', '`', '{', '}', '|', '~'])
# []
# False
# nan

# %%
jk_df2[jk_df2.index==12].values
# Out:
# array([[ '3-D Digital Imaging and Modeling, 2001. Proceedings. Third International Conference on',
#         13, nan,
#         '3D DIGITAL IMAGING AND MODELING 2001 PROCEEDINGS THIRD INTERNATIONAL CONFERENCE ON',
#         nan, 1,
#         '2001 PROCEEDINGS THIRD INTERNATIONAL CONFERENCE ON 3D DIGITAL IMAGING AND MODELING',
#         None]], dtype=object)

# %%
jk_df2[jk_df2['CONF_FLAG']==1].to_csv(join(RAW_DATA, 'conferences.csv'))

# %%
jk_df2[jk_df2['CONF_FLAG']==0].to_csv(join(RAW_DATA, 'journals_raw.csv'))

# %%
exact_matches.shape
# Out:
# (18, 11)

# %%
incites_not_matched = incites_df[~incites_df['CLEAN_PUB'].isin(exact_matches.index)]

# %%
exact_matches2 = pd.merge(
    left=not_match, right=incites_not_matched, left_on='CLEAN_PUB2', right_on='CLEAN_PUB', how='inner')

# %%
incites_not_matched2 = incites_not_matched[~incites_not_matched['CLEAN_PUB'].isin(exact_matches2.index)]
not_match2 = not_match.loc[~not_match['CLEAN_PUB2'].isin(exact_matches2['CLEAN_PUB']), :]

# %%
match_key = not_match.loc[pd.notnull(not_match.index), ['Publication Title']]

# %%
match_key2 = match_key.reset_index()
match_key2.rename(columns={'index': 'FULL_JOURNAL_TITLE'}, inplace=True)

# %%
full_matches = pd.concat([match_key2, exact_matches.loc[:, ['Publication Title', 'FULL_JOURNAL_TITLE']]], axis=0)

# %%
full_matches['score'] = full_matches[['Publication Title', 'FULL_JOURNAL_TITLE']].apply(lambda a: fuzz.token_sort_ratio(a[0], a[1]), axis=1)

# %%
incites_df
# Out:
#                                                      RANK TOTAL_CITES  \
# FULL_JOURNAL_TITLE
# CA-A CANCER JOURNAL FOR CLINICIANS                      1      20,488
# NEW ENGLAND JOURNAL OF MEDICINE                         2     283,525
# NATURE REVIEWS DRUG DISCOVERY                           3      25,460
# LANCET                                                  4     195,553
# NATURE BIOTECHNOLOGY                                    5      48,650
# NATURE REVIEWS IMMUNOLOGY                               6      31,545
# NATURE MATERIALS                                        7      72,306
# NATURE REVIEWS MOLECULAR CELL BIOLOGY                   8      36,784
# NATURE                                                  9     627,846
# Annual Review of Astronomy and Astrophysics            10       9,000
# JAMA-JOURNAL OF THE AMERICAN MEDICAL ASSOCIATION       11     129,909
# CHEMICAL REVIEWS                                       12     148,154
# NATURE REVIEWS GENETICS                                13      30,286
# Annual Review of Immunology                            14      17,023
# Nature Nanotechnology                                  15      40,881
# SCIENCE                                                16     568,210
# NATURE REVIEWS CANCER                                  17      41,846
# CHEMICAL SOCIETY REVIEWS                               18      99,930
# REVIEWS OF MODERN PHYSICS                              19      41,133
# Living Reviews in Relativity                           20       2,038
# NATURE GENETICS                                        21      86,870
# Nature Photonics                                       22      28,381
# PROGRESS IN MATERIALS SCIENCE                          23       9,196
# PHYSIOLOGICAL REVIEWS                                  24      24,788
# NATURE MEDICINE                                        25      65,230
# NATURE REVIEWS NEUROSCIENCE                            26      33,792
# CELL                                                   27     202,467
# Nature Chemistry                                       28      21,232
# PROGRESS IN POLYMER SCIENCE                            29      21,240
# LANCET ONCOLOGY                                        30      30,800
# ...                                                   ...         ...
# Traitement du Signal                                11949          37
# ACS Biomaterials-Science & Engineering              11962          73
# ACS Infectious Diseases                             11962          41
# Advanced Electronic Materials                       11962          90
# Aerospace Medicine and Human Performance            11962          28
# Anaesthesia Critical Care & Pain Medicine           11962          25
# Annual Review of Linguistics                        11962           9
# Austrian Journal of Political Science               11962           7
# Digital Scholarship in the Humanities               11962           6
# Environmental Science-Water Research & Technology   11962          59
# Frontiers of Information Technology & Electroni...  11962           1
# Health Promotion and Chronic Disease Prevention...  11962           4
# Health Security                                     11962           7
# Horticulture Journal                                11962          20
# Infectious Diseases                                 11962          25
# International Journal of Health  Economics and ...  11962           3
# Journal of Demographic Economics                    11962           2
# Journal of Service Theory and Practice              11962           6
# Mammal Research                                     11962          16
# NEPHRON                                             11962       2,303
# Nature Plants                                       11962         242
# Open Chemistry                                      11962          26
# Open Geosciences                                    11962           3
# Open Life Sciences                                  11962           5
# Open Mathematics                                    11962          15
# Open Physics                                        11962          20
# Papers in Palaeontology                             11962          13
# Science Bulletin                                    11962         163
# Science and Technology for the Built Environment    11962          11
# Science of Nature                                   11962          13
#
#                                                    JOURNAL_IMPACT_FACTOR  \
# FULL_JOURNAL_TITLE
# CA-A CANCER JOURNAL FOR CLINICIANS                               131.723
# NEW ENGLAND JOURNAL OF MEDICINE                                   59.558
# NATURE REVIEWS DRUG DISCOVERY                                      47.12
# LANCET                                                            44.002
# NATURE BIOTECHNOLOGY                                              43.113
# NATURE REVIEWS IMMUNOLOGY                                         39.416
# NATURE MATERIALS                                                  38.891
# NATURE REVIEWS MOLECULAR CELL BIOLOGY                             38.602
# NATURE                                                            38.138
# Annual Review of Astronomy and Astrophysics                       37.846
# JAMA-JOURNAL OF THE AMERICAN MEDICAL ASSOCIATION                  37.684
# CHEMICAL REVIEWS                                                  37.369
# NATURE REVIEWS GENETICS                                           35.898
# Annual Review of Immunology                                       35.543
# Nature Nanotechnology                                             35.267
# SCIENCE                                                           34.661
# NATURE REVIEWS CANCER                                             34.244
# CHEMICAL SOCIETY REVIEWS                                           34.09
# REVIEWS OF MODERN PHYSICS                                         33.177
# Living Reviews in Relativity                                          32
# NATURE GENETICS                                                   31.616
# Nature Photonics                                                  31.167
# PROGRESS IN MATERIALS SCIENCE                                     31.083
# PHYSIOLOGICAL REVIEWS                                             30.924
# NATURE MEDICINE                                                   30.357
# NATURE REVIEWS NEUROSCIENCE                                       29.298
# CELL                                                               28.71
# Nature Chemistry                                                  27.893
# PROGRESS IN POLYMER SCIENCE                                       27.184
# LANCET ONCOLOGY                                                   26.509
# ...                                                                  ...
# Traitement du Signal                                                   0
# ACS Biomaterials-Science & Engineering                     Not Available
# ACS Infectious Diseases                                    Not Available
# Advanced Electronic Materials                              Not Available
# Aerospace Medicine and Human Performance                   Not Available
# Anaesthesia Critical Care & Pain Medicine                  Not Available
# Annual Review of Linguistics                               Not Available
# Austrian Journal of Political Science                      Not Available
# Digital Scholarship in the Humanities                      Not Available
# Environmental Science-Water Research & Technology          Not Available
# Frontiers of Information Technology & Electroni...         Not Available
# Health Promotion and Chronic Disease Prevention...         Not Available
# Health Security                                            Not Available
# Horticulture Journal                                       Not Available
# Infectious Diseases                                        Not Available
# International Journal of Health  Economics and ...         Not Available
# Journal of Demographic Economics                           Not Available
# Journal of Service Theory and Practice                     Not Available
# Mammal Research                                            Not Available
# NEPHRON                                                    Not Available
# Nature Plants                                              Not Available
# Open Chemistry                                             Not Available
# Open Geosciences                                           Not Available
# Open Life Sciences                                         Not Available
# Open Mathematics                                           Not Available
# Open Physics                                               Not Available
# Papers in Palaeontology                                    Not Available
# Science Bulletin                                           Not Available
# Science and Technology for the Built Environment           Not Available
# Science of Nature                                          Not Available
#
#                                                     EIGENFACTOR_SCORE  \
# FULL_JOURNAL_TITLE
# CA-A CANCER JOURNAL FOR CLINICIANS                            0.06261
# NEW ENGLAND JOURNAL OF MEDICINE                               0.68563
# NATURE REVIEWS DRUG DISCOVERY                                 0.06294
# LANCET                                                        0.40817
# NATURE BIOTECHNOLOGY                                          0.15771
# NATURE REVIEWS IMMUNOLOGY                                     0.08760
# NATURE MATERIALS                                              0.20799
# NATURE REVIEWS MOLECULAR CELL BIOLOGY                         0.09969
# NATURE                                                        1.44762
# Annual Review of Astronomy and Astrophysics                   0.02021
# JAMA-JOURNAL OF THE AMERICAN MEDICAL ASSOCIATION              0.27518
# CHEMICAL REVIEWS                                              0.24548
# NATURE REVIEWS GENETICS                                       0.10725
# Annual Review of Immunology                                   0.03670
# Nature Nanotechnology                                         0.16769
# SCIENCE                                                       1.15726
# NATURE REVIEWS CANCER                                         0.08819
# CHEMICAL SOCIETY REVIEWS                                      0.27041
# REVIEWS OF MODERN PHYSICS                                     0.09735
# Living Reviews in Relativity                                  0.00737
# NATURE GENETICS                                               0.25530
# Nature Photonics                                              0.13589
# PROGRESS IN MATERIALS SCIENCE                                 0.01680
# PHYSIOLOGICAL REVIEWS                                         0.03565
# NATURE MEDICINE                                               0.16250
# NATURE REVIEWS NEUROSCIENCE                                   0.07267
# CELL                                                          0.55725
# Nature Chemistry                                              0.10334
# PROGRESS IN POLYMER SCIENCE                                   0.03305
# LANCET ONCOLOGY                                               0.11751
# ...                                                               ...
# Traitement du Signal                                          0.00002
# ACS Biomaterials-Science & Engineering                        0.00001
# ACS Infectious Diseases                                       0.00079
# Advanced Electronic Materials                                 0.00000
# Aerospace Medicine and Human Performance                      0.00000
# Anaesthesia Critical Care & Pain Medicine                     0.00000
# Annual Review of Linguistics                                  0.00000
# Austrian Journal of Political Science                         0.00000
# Digital Scholarship in the Humanities                         0.00000
# Environmental Science-Water Research & Technology             0.00001
# Frontiers of Information Technology & Electroni...            0.00000
# Health Promotion and Chronic Disease Prevention...            0.00000
# Health Security                                               0.00000
# Horticulture Journal                                          0.00012
# Infectious Diseases                                           0.00001
# International Journal of Health  Economics and ...            0.00000
# Journal of Demographic Economics                              0.00000
# Journal of Service Theory and Practice                        0.00000
# Mammal Research                                               0.00000
# NEPHRON                                                       0.00004
# Nature Plants                                                 0.00000
# Open Chemistry                                                0.00000
# Open Geosciences                                              0.00001
# Open Life Sciences                                            0.00000
# Open Mathematics                                              0.00000
# Open Physics                                                  0.00012
# Papers in Palaeontology                                       0.00003
# Science Bulletin                                              0.00000
# Science and Technology for the Built Environment              0.00000
# Science of Nature                                             0.00000
#
#                                                                                             CLEAN_PUB
# FULL_JOURNAL_TITLE
# CA-A CANCER JOURNAL FOR CLINICIANS                                  CAA CANCER JOURNAL FOR CLINICIANS
# NEW ENGLAND JOURNAL OF MEDICINE                                       NEW ENGLAND JOURNAL OF MEDICINE
# NATURE REVIEWS DRUG DISCOVERY                                           NATURE REVIEWS DRUG DISCOVERY
# LANCET                                                                                         LANCET
# NATURE BIOTECHNOLOGY                                                             NATURE BIOTECHNOLOGY
# NATURE REVIEWS IMMUNOLOGY                                                   NATURE REVIEWS IMMUNOLOGY
# NATURE MATERIALS                                                                     NATURE MATERIALS
# NATURE REVIEWS MOLECULAR CELL BIOLOGY                           NATURE REVIEWS MOLECULAR CELL BIOLOGY
# NATURE                                                                                         NATURE
# Annual Review of Astronomy and Astrophysics               ANNUAL REVIEW OF ASTRONOMY AND ASTROPHYSICS
# JAMA-JOURNAL OF THE AMERICAN MEDICAL ASSOCIATION      JAMAJOURNAL OF THE AMERICAN MEDICAL ASSOCIATION
# CHEMICAL REVIEWS                                                                     CHEMICAL REVIEWS
# NATURE REVIEWS GENETICS                                                       NATURE REVIEWS GENETICS
# Annual Review of Immunology                                               ANNUAL REVIEW OF IMMUNOLOGY
# Nature Nanotechnology                                                           NATURE NANOTECHNOLOGY
# SCIENCE                                                                                       SCIENCE
# NATURE REVIEWS CANCER                                                           NATURE REVIEWS CANCER
# CHEMICAL SOCIETY REVIEWS                                                     CHEMICAL SOCIETY REVIEWS
# REVIEWS OF MODERN PHYSICS                                                   REVIEWS OF MODERN PHYSICS
# Living Reviews in Relativity                                             LIVING REVIEWS IN RELATIVITY
# NATURE GENETICS                                                                       NATURE GENETICS
# Nature Photonics                                                                     NATURE PHOTONICS
# PROGRESS IN MATERIALS SCIENCE                                           PROGRESS IN MATERIALS SCIENCE
# PHYSIOLOGICAL REVIEWS                                                           PHYSIOLOGICAL REVIEWS
# NATURE MEDICINE                                                                       NATURE MEDICINE
# NATURE REVIEWS NEUROSCIENCE                                               NATURE REVIEWS NEUROSCIENCE
# CELL                                                                                             CELL
# Nature Chemistry                                                                     NATURE CHEMISTRY
# PROGRESS IN POLYMER SCIENCE                                               PROGRESS IN POLYMER SCIENCE
# LANCET ONCOLOGY                                                                       LANCET ONCOLOGY
# ...                                                                                               ...
# Traitement du Signal                                                             TRAITEMENT DU SIGNAL
# ACS Biomaterials-Science & Engineering                           ACS BIOMATERIALSSCIENCE  ENGINEERING
# ACS Infectious Diseases                                                       ACS INFECTIOUS DISEASES
# Advanced Electronic Materials                                           ADVANCED ELECTRONIC MATERIALS
# Aerospace Medicine and Human Performance                     AEROSPACE MEDICINE AND HUMAN PERFORMANCE
# Anaesthesia Critical Care & Pain Medicine                    ANAESTHESIA CRITICAL CARE  PAIN MEDICINE
# Annual Review of Linguistics                                             ANNUAL REVIEW OF LINGUISTICS
# Austrian Journal of Political Science                           AUSTRIAN JOURNAL OF POLITICAL SCIENCE
# Digital Scholarship in the Humanities                           DIGITAL SCHOLARSHIP IN THE HUMANITIES
# Environmental Science-Water Research & Technology     ENVIRONMENTAL SCIENCEWATER RESEARCH  TECHNOLOGY
# Frontiers of Information Technology & Electroni...  FRONTIERS OF INFORMATION TECHNOLOGY  ELECTRONI...
# Health Promotion and Chronic Disease Prevention...  HEALTH PROMOTION AND CHRONIC DISEASE PREVENTIO...
# Health Security                                                                       HEALTH SECURITY
# Horticulture Journal                                                             HORTICULTURE JOURNAL
# Infectious Diseases                                                               INFECTIOUS DISEASES
# International Journal of Health  Economics and ...  INTERNATIONAL JOURNAL OF HEALTH  ECONOMICS AND...
# Journal of Demographic Economics                                     JOURNAL OF DEMOGRAPHIC ECONOMICS
# Journal of Service Theory and Practice                         JOURNAL OF SERVICE THEORY AND PRACTICE
# Mammal Research                                                                       MAMMAL RESEARCH
# NEPHRON                                                                                       NEPHRON
# Nature Plants                                                                           NATURE PLANTS
# Open Chemistry                                                                         OPEN CHEMISTRY
# Open Geosciences                                                                     OPEN GEOSCIENCES
# Open Life Sciences                                                                 OPEN LIFE SCIENCES
# Open Mathematics                                                                     OPEN MATHEMATICS
# Open Physics                                                                             OPEN PHYSICS
# Papers in Palaeontology                                                       PAPERS IN PALAEONTOLOGY
# Science Bulletin                                                                     SCIENCE BULLETIN
# Science and Technology for the Built Environment     SCIENCE AND TECHNOLOGY FOR THE BUILT ENVIRONMENT
# Science of Nature                                                                   SCIENCE OF NATURE
#
# [11990 rows x 5 columns]

# %%
# only keep matches where score is above 90
incites_df2 = incites_df.reset_index(drop=False)
full_match2 = pd.merge(
    left=full_matches[full_matches['score'] > 90], right=incites_df2, left_on='FULL_JOURNAL_TITLE', 
    right_on='FULL_JOURNAL_TITLE', how='left')

# %%
full_match3 = pd.merge(
    left=full_match2, right=jk_df2[jk_df2['CONF_FLAG']==0], on='Publication Title', how='left')

# %%
full_match3
# Out:
#    CLEAN_PUB_x                       FULL_JOURNAL_TITLE  \
# 0          NaN                  PROCEEDINGS OF THE IEEE
# 1          NaN                 EVOLUTIONARY COMPUTATION
# 2          NaN                  APPLIED PHYSICS LETTERS
# 3          NaN               JOURNAL OF APPLIED PHYSICS
# 4          NaN                       NEURAL COMPUTATION
# 5          NaN                       LINGUISTIC INQUIRY
# 6          NaN       COMPUTING IN SCIENCE & ENGINEERING
# 7          NaN         REVIEW OF SCIENTIFIC INSTRUMENTS
# 8          NaN              BELL LABS TECHNICAL JOURNAL
# 9          NaN                                 COMPUTER
# 10         NaN                          IT Professional
# 11         NaN          TSINGHUA SCIENCE AND TECHNOLOGY
# 12         NaN                          ARTIFICIAL LIFE
# 13         NaN                      ELECTRONICS LETTERS
# 14         NaN  IBM JOURNAL OF RESEARCH AND DEVELOPMENT
# 15         NaN           Engineering Management Journal
# 16         NaN           Engineering Management Journal
# 17         NaN           Engineering Management Journal
# 18         NaN           Engineering Management Journal
# 19         NaN                   COMPUTER MUSIC JOURNAL
#
#                           Publication Title  score   RANK TOTAL_CITES  \
# 0                   Proceedings of the IEEE    100    528      21,036
# 1                  Evolutionary Computation    100   1368       2,291
# 2                   Applied Physics Letters    100   1783     222,233
# 3                Journal of Applied Physics    100   3559     151,547
# 4                        Neural Computation    100   4934       7,931
# 5                        Linguistic Inquiry    100   5354       2,055
# 6        Computing in Science & Engineering    100   5893       1,689
# 7          Review of Scientific Instruments    100   5992      25,970
# 8               Bell Labs Technical Journal    100   6564         380
# 9                                  Computer    100   6922       4,148
# 10                          IT Professional    100   7129         350
# 11          Tsinghua Science and Technology    100   7150         654
# 12                          Artificial Life    100   7243         624
# 13                      Electronics Letters    100   8180      14,098
# 14  IBM Journal of Research and Development    100   9374       2,755
# 15           Engineering Management Journal    100  10269         231
# 16           Engineering Management Journal    100  10269         231
# 17           Engineering Management Journal    100  10269         231
# 18           Engineering Management Journal    100  10269         231
# 19                   Computer Music Journal    100  11202         287
#
#    JOURNAL_IMPACT_FACTOR  EIGENFACTOR_SCORE  \
# 0                  5.629            0.03984
# 1                    3.6            0.00280
# 2                  3.142            0.38389
# 3                  2.101            0.20483
# 4                  1.626            0.00775
# 5                  1.511            0.00215
# 6                  1.361            0.00471
# 7                  1.336            0.04791
# 8                    1.2            0.00142
# 9                  1.115            0.00623
# 10                 1.067            0.00094
# 11                 1.063            0.00136
# 12                 1.042            0.00094
# 13                 0.854            0.02494
# 14                 0.626            0.00184
# 15                 0.468            0.00025
# 16                 0.468            0.00025
# 17                 0.468            0.00025
# 18                 0.468            0.00025
# 19                 0.279            0.00010
#
#                                 CLEAN_PUB_y  JournalID  InCites Spelling  \
# 0                   PROCEEDINGS OF THE IEEE      12912               NaN
# 1                  EVOLUTIONARY COMPUTATION       5194               NaN
# 2                   APPLIED PHYSICS LETTERS        893               NaN
# 3                JOURNAL OF APPLIED PHYSICS      10157               NaN
# 4                        NEURAL COMPUTATION      11644               NaN
# 5                        LINGUISTIC INQUIRY      10284               NaN
# 6         COMPUTING IN SCIENCE  ENGINEERING       3019               NaN
# 7          REVIEW OF SCIENTIFIC INSTRUMENTS      13571               NaN
# 8               BELL LABS TECHNICAL JOURNAL       1238               NaN
# 9                                  COMPUTER       2439               NaN
# 10                          IT PROFESSIONAL      10140               NaN
# 11          TSINGHUA SCIENCE AND TECHNOLOGY      15870               NaN
# 12                          ARTIFICIAL LIFE        985               NaN
# 13                      ELECTRONICS LETTERS       4647               NaN
# 14  IBM JOURNAL OF RESEARCH AND DEVELOPMENT       6043               NaN
# 15           ENGINEERING MANAGEMENT JOURNAL       5025               NaN
# 16           ENGINEERING MANAGEMENT JOURNAL       5025               NaN
# 17           ENGINEERING MANAGEMENT JOURNAL       5025               NaN
# 18           ENGINEERING MANAGEMENT JOURNAL       5025               NaN
# 19                   COMPUTER MUSIC JOURNAL       2695               NaN
#
#                                   CLEAN_PUB  AdjustedJournalID  CONF_FLAG
# 0                   PROCEEDINGS OF THE IEEE                NaN          0
# 1                  EVOLUTIONARY COMPUTATION                NaN          0
# 2                   APPLIED PHYSICS LETTERS                NaN          0
# 3                JOURNAL OF APPLIED PHYSICS                NaN          0
# 4                        NEURAL COMPUTATION                NaN          0
# 5                        LINGUISTIC INQUIRY                NaN          0
# 6         COMPUTING IN SCIENCE  ENGINEERING                NaN          0
# 7          REVIEW OF SCIENTIFIC INSTRUMENTS                NaN          0
# 8               BELL LABS TECHNICAL JOURNAL                NaN          0
# 9                                  COMPUTER                NaN          0
# 10                          IT PROFESSIONAL                NaN          0
# 11          TSINGHUA SCIENCE AND TECHNOLOGY                NaN          0
# 12                          ARTIFICIAL LIFE                NaN          0
# 13                      ELECTRONICS LETTERS                NaN          0
# 14  IBM JOURNAL OF RESEARCH AND DEVELOPMENT                NaN          0
# 15           ENGINEERING MANAGEMENT JOURNAL                NaN          0
# 16           ENGINEERING MANAGEMENT JOURNAL                NaN          0
# 17           ENGINEERING MANAGEMENT JOURNAL                NaN          0
# 18           ENGINEERING MANAGEMENT JOURNAL                NaN          0
# 19                   COMPUTER MUSIC JOURNAL                NaN          0

# %%
# for the conferences, check if any of these e

# %%
# full_match3[full_match3['CLEAN_PUB_x'].str.contains('TRANSACTIONS ON INDUSTRIAL')]
mag_str = 'SIGNAL PROCESSING MAGAZINE'
incites_df[incites_df['CLEAN_PUB'].str.contains(mag_str)]
jk_df2[jk_df2['CLEAN_PUB'].str.contains(mag_str)]
not_match[not_match['CLEAN_PUB2'].str.contains(mag_str)]
incites_not_matched[incites_not_matched.index.str.contains(mag_str)]
# jk_df2[jk_df2['CONF_FLAG']==0]
# full_match3[full_match3['CLEAN_PUB'].str.contains('SIGNAL PROCESSING')]
# Out:
#                                  RANK TOTAL_CITES JOURNAL_IMPACT_FACTOR  \
# FULL_JOURNAL_TITLE
# IEEE SIGNAL PROCESSING MAGAZINE   383       6,140                 6.671
#
#                                  EIGENFACTOR_SCORE  \
# FULL_JOURNAL_TITLE
# IEEE SIGNAL PROCESSING MAGAZINE            0.01866
#
#                                                        CLEAN_PUB
# FULL_JOURNAL_TITLE
# IEEE SIGNAL PROCESSING MAGAZINE  IEEE SIGNAL PROCESSING MAGAZINE

# %%
incites_df[in]
# Out:
#                                     FULL_JOURNAL_TITLE  \
# 0                           SOCIAL HISTORY OF MEDICINE
# 1       IEEE AEROSPACE AND ELECTRONIC SYSTEMS MAGAZINE
# 2       IEEE AEROSPACE AND ELECTRONIC SYSTEMS MAGAZINE
# 3    JOURNAL OF BIOMECHANICAL ENGINEERING-TRANSACTI...
# 4              IEEE ANNALS OF THE HISTORY OF COMPUTING
# 5              IEEE ANNALS OF THE HISTORY OF COMPUTING
# 6               IEEE ANTENNAS AND PROPAGATION MAGAZINE
# 7               IEEE ANTENNAS AND PROPAGATION MAGAZINE
# 8               IEEE ANTENNAS AND PROPAGATION MAGAZINE
# 9               IEEE ANTENNAS AND PROPAGATION MAGAZINE
# 10                 JOURNAL OF ENVIRONMENTAL MANAGEMENT
# 11    PHYSICA C-SUPERCONDUCTIVITY AND ITS APPLICATIONS
# 12                                    IIE TRANSACTIONS
# 13                    BIOCHEMICAL SOCIETY TRANSACTIONS
# 14                      SCIENCE AND ENGINEERING ETHICS
# 15                       MEDICAL ENGINEERING & PHYSICS
# 16   JOURNAL OF BIOMECHANICAL ENGINEERING-TRANSACTI...
# 17                                          BIOMETRICS
# 18                        IEEE WIRELESS COMMUNICATIONS
# 19                                 DALTON TRANSACTIONS
# 20                                    IIE TRANSACTIONS
# 21                       IEEE CONTROL SYSTEMS MAGAZINE
# 22   IEEE TRANSACTIONS ON CIRCUITS AND SYSTEMS FOR ...
# 23   IEEE TRANSACTIONS ON CIRCUITS AND SYSTEMS I-RE...
# 24              CIRCUITS SYSTEMS AND SIGNAL PROCESSING
# 25   IEEE TRANSACTIONS ON CIRCUITS AND SYSTEMS II-E...
# 26                       IEEE CONTROL SYSTEMS MAGAZINE
# 27              CIRCUITS SYSTEMS AND SIGNAL PROCESSING
# 28              CIRCUITS SYSTEMS AND SIGNAL PROCESSING
# 29              CIRCUITS SYSTEMS AND SIGNAL PROCESSING
# ..                                                 ...
# 248             TRANSPORTATION PLANNING AND TECHNOLOGY
# 249  IEEE TRANSACTIONS ON ULTRASONICS FERROELECTRIC...
# 250  IEEE TRANSACTIONS ON ULTRASONICS FERROELECTRIC...
# 251  APPLIED COMPUTATIONAL ELECTROMAGNETICS SOCIETY...
# 252               IEEE TECHNOLOGY AND SOCIETY MAGAZINE
# 253                             TRIBOLOGY TRANSACTIONS
# 254  IEEE TRANSACTIONS ON VERY LARGE SCALE INTEGRAT...
# 255                        IEEE COMMUNICATIONS LETTERS
# 256                       IEEE WIRELESS COMMUNICATIONS
# 257         WIRELESS COMMUNICATIONS & MOBILE COMPUTING
# 258                      IEEE CONTROL SYSTEMS MAGAZINE
# 259                    POLYMER ENGINEERING AND SCIENCE
# 0                              PROCEEDINGS OF THE IEEE
# 1                             EVOLUTIONARY COMPUTATION
# 2                              APPLIED PHYSICS LETTERS
# 3                           JOURNAL OF APPLIED PHYSICS
# 4                                   NEURAL COMPUTATION
# 5                                   LINGUISTIC INQUIRY
# 6                   COMPUTING IN SCIENCE & ENGINEERING
# 7                     REVIEW OF SCIENTIFIC INSTRUMENTS
# 8                          BELL LABS TECHNICAL JOURNAL
# 9                                             COMPUTER
# 10                                     IT Professional
# 11                     TSINGHUA SCIENCE AND TECHNOLOGY
# 12                                     ARTIFICIAL LIFE
# 13                                 ELECTRONICS LETTERS
# 14             IBM JOURNAL OF RESEARCH AND DEVELOPMENT
# 15                      Engineering Management Journal
# 16                      Engineering Management Journal
# 17                              COMPUTER MUSIC JOURNAL
#
#                                      Publication Title  score
# 0                      A Social History of Engineering     60
# 1      Aerospace and Electronic Systems Magazine, IEEE    100
# 2    Aerospace and Electronic Systems, IEEE Transac...     79
# 3    American Institute of Electrical Engineers, Tr...     75
# 4                   Annals of the History of Computing     93
# 5             Annals of the History of Computing, IEEE    100
# 6              Antennas and Propagation Magazine, IEEE    100
# 7       Antennas and Propagation, IEEE Transactions on     75
# 8        Antennas and Propagation, IRE Transactions on     71
# 9      Antennas and Wireless Propagation Letters, IEEE     74
# 10   Applied Industrial Energy and Environmental Ma...     65
# 11     Applied Superconductivity, IEEE Transactions on     55
# 12                          Audio, IRE Transactions on     78
# 13             Automatic Control, IEEE Transactions on     60
# 14   Automation Science and Engineering, IEEE Trans...     59
# 15             Biomedical Engineering, IEEE Reviews in     52
# 16        Biomedical Engineering, IEEE Transactions on     71
# 17                                     Biometrics, IET     83
# 18   Body-Centric Wireless Communications, IET Semi...     68
# 19                  Broadcasting, IEEE Transactions on     69
# 20                   Broadcasting, IRE Transactions on     67
# 21                         Circuits & Systems Magazine     74
# 22   Circuits and Systems for Video Technology, IEE...    100
# 23   Circuits and Systems I: Regular Papers, IEEE T...    100
# 24   Circuits and Systems II: Analog and Digital Si...     64
# 25   Circuits and Systems II: Express Briefs, IEEE ...    100
# 26                 Circuits and Systems Magazine, IEEE     76
# 27      Circuits, Devices and Systems, IEE Proceedings     73
# 28    Circuits, Devices and Systems, IEE Proceedings -     73
# 29    Circuits, Devices and Systems, IEE Proceedings G     71
# ..                                                 ...    ...
# 248      Transportation in a Climate-Constrained World     58
# 249  Ultrasonics, Ferroelectrics and Frequency Cont...    100
# 250  Ultrasonics, Ferroelectrics, and Frequency Con...    100
# 251  Validation of Computational Electromagnetics, ...     65
# 252                Vehicular Technology Magazine, IEEE     69
# 253         Vehicular Technology, IEEE Transactions on     48
# 254  Very Large Scale Integration (VLSI) Systems, I...    100
# 255              Wireless Communications Letters, IEEE     86
# 256                      Wireless Communications, IEEE    100
# 257      Wireless Communications, IEEE Transactions on     67
# 258                       Wireless Sensor Systems, IET     43
# 259                Women in Engineering Magazine, IEEE     52
# 0                              Proceedings of the IEEE    100
# 1                             Evolutionary Computation    100
# 2                              Applied Physics Letters    100
# 3                           Journal of Applied Physics    100
# 4                                   Neural Computation    100
# 5                                   Linguistic Inquiry    100
# 6                   Computing in Science & Engineering    100
# 7                     Review of Scientific Instruments    100
# 8                          Bell Labs Technical Journal    100
# 9                                             Computer    100
# 10                                     IT Professional    100
# 11                     Tsinghua Science and Technology    100
# 12                                     Artificial Life    100
# 13                                 Electronics Letters    100
# 14             IBM Journal of Research and Development    100
# 15                      Engineering Management Journal    100
# 16                      Engineering Management Journal    100
# 17                              Computer Music Journal    100
#
# [278 rows x 3 columns]

# %%
# merge match key with exact matches
exact_matches.set_index(keys='CLEAN_PUB', drop=True, inplace=True)
match_key_full = pd.concat([match_key, exact_matches.loc[:, ]])
# Out:
#                                                                                     Publication Title
# CLEAN_PUB
# 3D IMAGING AND ANALYSIS OF DEPTHRANGE IMAGES IE...  3D Imaging and Analysis of Depth/Range Images,...
# 80216K2007 AMENDMENT TO IEEE STD 8021D2004           802.16k-2007 (Amendment to IEEE Std 802.1D-2004)
# 80232005COR 22007 CORRIGENDUM TO IEEE STD 80232005  802.3-2005/Cor 2-2007 (Corrigendum to IEEE Std...
# A SOCIAL HISTORY OF ENGINEERING                                       A Social History of Engineering
# ACCESS IEEE                                                                              Access, IEEE
# ACOUSTICS SPEECH AND SIGNAL PROCESSING IEEE TRA...  Acoustics, Speech and Signal Processing, IEEE ...
# ACTIVE RF DEVICES CIRCUITS AND SYSTEMS SEMINAR        Active RF Devices, Circuits and Systems Seminar
# ADVANCED PACKAGING IEEE TRANSACTIONS ON                      Advanced Packaging, IEEE Transactions on
# ADVANCES IN RAILWAY COMMUNICATION SYSTEMS DIGES...  Advances in Railway Communication Systems. Dig...
# AEROSPACE AND ELECTRONIC SYSTEMS MAGAZINE IEEE        Aerospace and Electronic Systems Magazine, IEEE
# AEROSPACE AND ELECTRONIC SYSTEMS IEEE TRANSACTI...  Aerospace and Electronic Systems, IEEE Transac...
# AFFECTIVE COMPUTING IEEE TRANSACTIONS ON                    Affective Computing, IEEE Transactions on
# AIRCRAFT AIRBORNE CONDITION MONITORING IEE SEMI...  Aircraft Airborne Condition Monitoring, IEE Se...
# ALLOPTICAL NETWORKING EXISTING AND EMERGING ARC...  All-Optical Networking: Existing and Emerging ...
# AMERICAN INSTITUTE OF ELECTRICAL ENGINEERS PART...  American Institute of Electrical Engineers, Pa...
# AMERICAN INSTITUTE OF ELECTRICAL ENGINEERS TRAN...  American Institute of Electrical Engineers, Tr...
# ANNALS OF THE HISTORY OF COMPUTING                                 Annals of the History of Computing
# ANNALS OF THE HISTORY OF COMPUTING IEEE                      Annals of the History of Computing, IEEE
# ANSI C37062000                                                                       ANSI C37.06-2000
# ANSI C37221997                                                                       ANSI C37.22-1997
# ANSI C571 2251990                                                                ANSI C57.1 2.25-1990
# ANSI C5712201997                                                                  ANSI C57.12.20-1997
# ANSI C63102013                                                                       ANSI C63.10-2013
# ANSI C63102013  REDLINE                                                    ANSI C63.10-2013 - Redline
# ANSI C63142014 REVISION OF ANSI C63142009             ANSI C63.14-2014 (Revision of ANSI C63.14-2009)
# ANSI C63172006 REVISION OF ANSI C63171998             ANSI C63.17-2006 (Revision of ANSI C63.17-1998)
# ANSI C63172013                                                                       ANSI C63.17-2013
# ANSI C63172013  REDLINE                                                    ANSI C63.17-2013 - Redline
# ANSI C63182014 REVISION OF ANSI C63181997             ANSI C63.18-2014 (Revision of ANSI C63.18-1997)
# ANSI C63182014 REVISION OF ANSI C63181997  REDLINE  ANSI C63.18-2014 (Revision of ANSI C63.18-1997...
# ...                                                                                               ...
# SYSTEMS MAN AND CYBERNETICS SYSTEMS IEEE TRANSA...  Systems, Man, and Cybernetics: Systems, IEEE T...
# TARGET TRACKING ALGORITHMS AND APPLICATIONS REF...  Target Tracking: Algorithms and Applications (...
# TECHNOLOGY AND SOCIETY MAGAZINE IEEE                            Technology and Society Magazine, IEEE
# TECHNOLOGY MANAGEMENT A UNIFYING DISCIPLINE FOR...  Technology Management: A Unifying Discipline f...
# TECNOLOGIAS DEL APRENDIZAJE IEEE REVISTA IBEROA...  Tecnologias del Aprendizaje, IEEE Revista Iber...
# TELEGRAPH ENGINEERS JOURNAL OF THE SOCIETY OF          Telegraph Engineers, Journal of the Society of
# TELEGRAPHENGINEERS AND ELECTRICIANS JOURNAL OF ...  Telegraph-Engineers and Electricians, Journal ...
# TEMPORAL REASONING IEE COLLOQUIUM ON                            Temporal Reasoning, IEE Colloquium on
# TERAHERTZ SCIENCE AND TECHNOLOGY IEEE TRANSACTI...  Terahertz Science and Technology, IEEE Transac...
# THE APPLICATION OF IEC 61131 IN INDUSTRIAL CONT...  The Application of IEC 61131 in Industrial Con...
# VISION IMAGE AND SIGNAL PROCESSING IEE PROCEEDINGS  Vision, Image and Signal Processing, IEE Proce...
# VISION IMAGE AND SIGNAL PROCESSING IEE PROCEEDI...  Vision, Image and Signal Processing, IEE Proce...
# VISUALIZATION 97 PROCEEDINGS                                          Visualization '97., Proceedings
# VISUALIZATION AND COMPUTER GRAPHICS IEEE TRANSA...  Visualization and Computer Graphics, IEEE Tran...
# TRANSLATIONAL ENGINEERING IN HEALTH AND MEDICIN...  Translational Engineering in Health and Medici...
# TRANSPORTATION IN A CLIMATECONSTRAINED WORLD            Transportation in a Climate-Constrained World
# TUTORIAL ON HARDWARE AND SOFTWARE RELIABILITY M...  Tutorial on Hardware and Software Reliability,...
# UAVS IN THE CIVILIAN AIRSPACE IET SEMINAR ON            UAVs in the Civilian Airspace, IET Seminar on
# ULTRASONICS FERROELECTRICS AND FREQUENCY CONTRO...  Ultrasonics, Ferroelectrics and Frequency Cont...
# ULTRASONICS FERROELECTRICS AND FREQUENCY CONTRO...  Ultrasonics, Ferroelectrics, and Frequency Con...
# URBAN CONGESTION MANAGEMENT IEE COLLOQUIUM ON          Urban Congestion Management, IEE Colloquium on
# VALIDATION OF COMPUTATIONAL ELECTROMAGNETICS IE...  Validation of Computational Electromagnetics, ...
# VEHICULAR TECHNOLOGY MAGAZINE IEEE                                Vehicular Technology Magazine, IEEE
# VEHICULAR TECHNOLOGY IEEE TRANSACTIONS ON                  Vehicular Technology, IEEE Transactions on
# VERY LARGE SCALE INTEGRATION VLSI SYSTEMS IEEE ...  Very Large Scale Integration (VLSI) Systems, I...
# WIRELESS COMMUNICATIONS LETTERS IEEE                            Wireless Communications Letters, IEEE
# WIRELESS COMMUNICATIONS IEEE                                            Wireless Communications, IEEE
# WIRELESS COMMUNICATIONS IEEE TRANSACTIONS ON            Wireless Communications, IEEE Transactions on
# WIRELESS SENSOR SYSTEMS IET                                              Wireless Sensor Systems, IET
# WOMEN IN ENGINEERING MAGAZINE IEEE                                Women in Engineering Magazine, IEEE
#
# [2073 rows x 1 columns]

# %%
exact_matches
# Out:
#      RANK                       FULL_JOURNAL_TITLE TOTAL_CITES  \
# 0     528                  PROCEEDINGS OF THE IEEE      21,036
# 1    1368                 EVOLUTIONARY COMPUTATION       2,291
# 2    1783                  APPLIED PHYSICS LETTERS     222,233
# 3    3559               JOURNAL OF APPLIED PHYSICS     151,547
# 4    4934                       NEURAL COMPUTATION       7,931
# 5    5354                       LINGUISTIC INQUIRY       2,055
# 6    5893       COMPUTING IN SCIENCE & ENGINEERING       1,689
# 7    5992         REVIEW OF SCIENTIFIC INSTRUMENTS      25,970
# 8    6564              BELL LABS TECHNICAL JOURNAL         380
# 9    6922                                 COMPUTER       4,148
# 10   7129                          IT Professional         350
# 11   7150          TSINGHUA SCIENCE AND TECHNOLOGY         654
# 12   7243                          ARTIFICIAL LIFE         624
# 13   8180                      ELECTRONICS LETTERS      14,098
# 14   9374  IBM JOURNAL OF RESEARCH AND DEVELOPMENT       2,755
# 15  10269           Engineering Management Journal         231
# 16  10269           Engineering Management Journal         231
# 17  11202                   COMPUTER MUSIC JOURNAL         287
#
#    JOURNAL_IMPACT_FACTOR  EIGENFACTOR_SCORE  \
# 0                  5.629            0.03984
# 1                    3.6            0.00280
# 2                  3.142            0.38389
# 3                  2.101            0.20483
# 4                  1.626            0.00775
# 5                  1.511            0.00215
# 6                  1.361            0.00471
# 7                  1.336            0.04791
# 8                    1.2            0.00142
# 9                  1.115            0.00623
# 10                 1.067            0.00094
# 11                 1.063            0.00136
# 12                 1.042            0.00094
# 13                 0.854            0.02494
# 14                 0.626            0.00184
# 15                 0.468            0.00025
# 16                 0.468            0.00025
# 17                 0.279            0.00010
#
#                                   CLEAN_PUB  \
# 0                   PROCEEDINGS OF THE IEEE
# 1                  EVOLUTIONARY COMPUTATION
# 2                   APPLIED PHYSICS LETTERS
# 3                JOURNAL OF APPLIED PHYSICS
# 4                        NEURAL COMPUTATION
# 5                        LINGUISTIC INQUIRY
# 6         COMPUTING IN SCIENCE  ENGINEERING
# 7          REVIEW OF SCIENTIFIC INSTRUMENTS
# 8               BELL LABS TECHNICAL JOURNAL
# 9                                  COMPUTER
# 10                          IT PROFESSIONAL
# 11          TSINGHUA SCIENCE AND TECHNOLOGY
# 12                          ARTIFICIAL LIFE
# 13                      ELECTRONICS LETTERS
# 14  IBM JOURNAL OF RESEARCH AND DEVELOPMENT
# 15           ENGINEERING MANAGEMENT JOURNAL
# 16           ENGINEERING MANAGEMENT JOURNAL
# 17                   COMPUTER MUSIC JOURNAL
#
#                           Publication Title  JournalID  InCites Spelling  \
# 0                   Proceedings of the IEEE      12912               NaN
# 1                  Evolutionary Computation       5194               NaN
# 2                   Applied Physics Letters        893               NaN
# 3                Journal of Applied Physics      10157               NaN
# 4                        Neural Computation      11644               NaN
# 5                        Linguistic Inquiry      10284               NaN
# 6        Computing in Science & Engineering       3019               NaN
# 7          Review of Scientific Instruments      13571               NaN
# 8               Bell Labs Technical Journal       1238               NaN
# 9                                  Computer       2439               NaN
# 10                          IT Professional      10140               NaN
# 11          Tsinghua Science and Technology      15870               NaN
# 12                          Artificial Life        985               NaN
# 13                      Electronics Letters       4647               NaN
# 14  IBM Journal of Research and Development       6043               NaN
# 15           Engineering Management Journal       5025               NaN
# 16           Engineering Management Journal       5025               NaN
# 17                   Computer Music Journal       2695               NaN
#
#     AdjustedJournalID  CONF_FLAG
# 0                 NaN          0
# 1                 NaN          0
# 2                 NaN          0
# 3                 NaN          0
# 4                 NaN          0
# 5                 NaN          0
# 6                 NaN          0
# 7                 NaN          0
# 8                 NaN          0
# 9                 NaN          0
# 10                NaN          0
# 11                NaN          0
# 12                NaN          0
# 13                NaN          0
# 14                NaN          0
# 15                NaN          0
# 16                NaN          0
# 17                NaN          0

# %%
not_match['STR_SIM'] = not_match.loc[
    not_match['CONF_FLAG']==0, 'CLEAN_PUB'].apply(lambda x: calculate_str_sim(x, incites_strs))

# %%
# incites_df.loc[incites_df['CLEAN_PUB'].str.contains('WORLD OF WIRELESS'), :]
incites_df.loc[incites_df['CLEAN_PUB'].str.contains('WIRELESS'), :]

# %%
incites_df

# %%
# for each of the nonmatches, calculate string sim to each of journal titles
# use fuzz.token_set_ratio to control for out of order
# ex:
# 100 = fuzz.token_set_ratio('IEEE TRANSACTIONS ON WIRELESS COMMUNICATIONS', 'WIRELESS COMMUNICATIONS IEEE TRANSACTIONS ON')
def calculate_str_sim(journal_str, incites_strs):
    # for each of the incites_str, calculate strs_sim
    max_ratio = (0, None)
    for incite_str in incites_strs:
        r = fuzz.token_set_ratio(journal_str, incite_str)
        if r > max_ratio[0]:
            max_ratio = (r, incite_str)
    return max_ratio
